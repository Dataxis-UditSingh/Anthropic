# %%
#Loan Env Variable
import json
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
# Create an API Client 
from anthropic import Anthropic

client = Anthropic()
model = "claude-opus-4-5-20251101"

# %%
# Make a request

def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)

def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)

def chat(messages, system = None, stop_sequences=None):
    params = {
        "model" : model,
        "max_tokens" : 1000,
        "messages" : messages,
        # "temperature" : temperature,
    }
    if system:
        params["system"] = system
    
    if stop_sequences:
        params["stop_sequences"] = stop_sequences


    message = client.messages.create(**params)
    return message.content[0].text

# %%
#Make a starting list of messages
messages = []

#Add in the initailise user quastion of "Define Quantum Computing in one sentence"
add_user_message(messages, "Define Quantum Computing in one sentence")

# Pass the list of the message into 'chat' to get an answer
answer = chat(messages)

#take the answer and add it as assistant message into our list 
add_assistant_message(messages, answer)

#Add in the user's follow-up quastion 
add_user_message(messages, "Write another sentence")

answer = chat(messages)
# answer

# %%
def run_prompt(test_case):
    """Merges the prompt and test case input, then returns the result."""
    prompt = f"""
Please solve the following task:
{test_case["task"]}
* Respond only with Python, JSON, or a plain Regex
*Do not add any comments or commentary or explanation 
"""
    
    messages = []
    add_user_message(messages, prompt)
    add_assistant_message(messages, "```code")
    output = chat(messages, stop_sequences=["```"])
    return output

# %%
def grade_by_model(test_case, output):
    # Create evaluation prompt
    eval_prompt = f"""
    You are an expert code reviewer. Evaluate this AI-generated solution.
    
    OriginalTask: 
    <task>
    {test_case['task']}
    </task>
    Solution to Evaluate: 
    <solution>
    {output}    
    </solution>

    Criteria you should use to evaluate the solution:
    <criteria>
    {test_case['solution_criteria']}
    </criteria>

    Provide your evaluation as a structured JSON object with:
    - "strengths": An array of 1-3 key strengths
    - "weaknesses": An array of 1-3 key areas for improvement  
    - "reasoning": A concise explanation of your assessment
    - "score": A number between 1-10


    Response with JSON. Keep your response concise and direct.
    Example response shape:
    {{
    "strengths": string[],
    "weaknesses": string[],
    "reasoning": string,
    "score": number
    }}
    """

    messages = []
    add_user_message(messages, eval_prompt)
    add_assistant_message(messages, "```json")
    eval_text = chat(messages, stop_sequences=["```"])
    return json.loads(eval_text)

# %%
# Functions to validate the output structure
import re
import ast


def validate_json(text):
    try:
        json.loads(text.strip())
        return 10
    except json.JSONDecodeError:
        return 0


def validate_python(text):
    try:
        ast.parse(text.strip())
        return 10
    except SyntaxError:
        return 0


def validate_regex(text):
    try:
        re.compile(text.strip())
        return 10
    except re.error:
        return 0


def grade_syntax(response, test_case):
    format = test_case["format"]
    if format == "json":
        return validate_json(response)
    elif format == "python":
        return validate_python(response)
    else:
        return validate_regex(response)

# %%
def run_test_cases(test_cases):
    """Calls run_prompt, then grades the output."""
    output = run_prompt(test_cases)

    # TODO - Gradient
    model_grade = grade_by_model(test_cases, output)
    model_score = model_grade["score"]
    reasoning = model_grade["reasoning"]

    syntax_score = grade_syntax(output, test_cases)
    score = (model_score + syntax_score) / 2

    return{
        "output": output,
        "test_cases": test_cases,
        "score": score,
        "reasoning": reasoning
    }

# %%
from statistics import mean
def run_eval(dataset):
    """Load the dataset and call run_test_case with each case."""
    results = []
    for test_case in dataset:
        result = run_test_cases(test_case)
        results.append(result)

    average_score = mean([result["score"] for result in results])
    print(f"Average Score: {average_score}")
    
    return results

# %%
with open("dataset.json", "r") as f:
    dataset = json.load(f)

results = run_eval(dataset)
# Out:
# Average Score: 9.0

# %%
print(json.dumps(results, indent=2))
# Out:
# [
#   {
#     "output": "\nimport re\n\n\ndef extract_s3_bucket_names(arns: list[str]) -> list[str]:\n    bucket_names = []\n    pattern = r'^arn:aws:s3:::([a-zA-Z0-9.\\-_]+)'\n    \n    for arn in arns:\n        match = re.match(pattern, arn)\n        if match:\n            bucket_names.append(match.group(1))\n    \n    return bucket_names\n",
#     "test_cases": {
#       "task": "Write a Python function that extracts all S3 bucket names from a list of S3 ARNs (e.g., 'arn:aws:s3:::my-bucket-name')",
#       "format": "python",
#       "solution_criteria": "Function correctly parses ARN format, handles edge cases like empty lists, returns a list of bucket names without the ARN prefix"
#     },
#     "score": 8.5,
#     "reasoning": "The solution correctly addresses the core task of extracting bucket names from S3 ARNs. It handles the basic ARN format 'arn:aws:s3:::bucket-name' and empty lists. However, the regex pattern includes underscores which are not valid S3 bucket name characters (only lowercase letters, numbers, hyphens, and periods are allowed). The pattern also doesn't account for AWS GovCloud or China regions which use 'arn:aws-us-gov:s3' or 'arn:aws-cn:s3'. Despite these edge case issues, the solution works correctly for standard S3 bucket ARNs."
#   },
#   {
#     "output": "\n{\n    \"Version\": \"2012-10-17\",\n    \"Statement\": [\n        {\n            \"Sid\": \"DynamoDBReadOnlyAccess\",\n            \"Effect\": \"Allow\",\n            \"Action\": [\n                \"dynamodb:GetItem\",\n                \"dynamodb:BatchGetItem\",\n                \"dynamodb:Scan\",\n                \"dynamodb:Query\",\n                \"dynamodb:DescribeTable\"\n            ],\n            \"Resource\": \"arn:aws:dynamodb:us-east-1:*:table/users-table\"\n        }\n    ]\n}\n",
#     "test_cases": {
#       "task": "Create an IAM policy JSON document that allows read-only access to a specific DynamoDB table named 'users-table' in the us-east-1 region",
#       "format": "json",
#       "solution_criteria": "Valid IAM policy structure with correct Version field, properly scoped Resource ARN for the specific table, includes only read actions (GetItem, Query, Scan, DescribeTable)"
#     },
#     "score": 9.0,
#     "reasoning": "The solution meets all the specified criteria. It has valid IAM policy syntax, properly restricts access to only read operations, and scopes the resource to the specific DynamoDB table in us-east-1. The inclusion of BatchGetItem is a reasonable addition for read-only access. The main concern is the wildcard account ID, which while functional, is less secure than specifying the exact account. The policy also doesn't cover index resources, but this may be intentional depending on requirements."
#   },
#   {
#     "output": "\n^[a-zA-Z0-9_-]{1,64}$\n",
#     "test_cases": {
#       "task": "Write a regex pattern that validates AWS Lambda function names, which must be 1-64 characters long and can only contain letters, numbers, hyphens, and underscores",
#       "format": "regex",
#       "solution_criteria": "Pattern enforces length constraints (1-64 chars), only allows valid characters [a-zA-Z0-9_-], anchored to match the entire string"
#     },
#     "score": 9.5,
#     "reasoning": "The solution meets all the explicitly stated criteria: it enforces the 1-64 character length, only allows the specified valid characters [a-zA-Z0-9_-], and is properly anchored. However, according to actual AWS Lambda naming conventions, function names should start with a letter, which this pattern doesn't enforce. For the requirements as literally stated in the task, this is a correct solution."
#   }
# ]
